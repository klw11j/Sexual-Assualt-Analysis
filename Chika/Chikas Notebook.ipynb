# %%
#import dependencies

import requests
import pandas as pd
import io
from datetime import date
import numpy as np

#Read CSV
df = pd.read_csv("../Data/totalsGender_global_dataset_2020.csv")


df.head(10)
# Out:
#    yearOfRegistration  gender  meansOfControlTakesEarnings  \
# 0                2015  Female                           66
# 1                2016  Female                          104
# 2                2016    Male                            0
# 3                2017  Female                          100
# 4                2018  Female                           60
# 5                2018    Male                            0
#
#    meansOfControlThreats  meansOfControlPsychologicalAbuse  \
# 0                    108                               177
# 1                    236                               301
# 2                      0                                 0
# 3                    294                               306
# 4                    180                               233
# 5                      5                                10
#
#    meansOfControlPhysicalAbuse  meansOfControlSexualAbuse  \
# 0                          133                         57
# ...

# %%
df_table = df.to_html(classes="table table-striped")
print(df_table)
# Out:
# <table border="1" class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearOfRegistration</th>
#       <th>gender</th>
#       <th>meansOfControlTakesEarnings</th>
#       <th>meansOfControlThreats</th>
#       <th>meansOfControlPsychologicalAbuse</th>
#       <th>meansOfControlPhysicalAbuse</th>
#       <th>meansOfControlSexualAbuse</th>
#       <th>meansOfControlPsychoactiveSubstances</th>
#       <th>meansOfControlRestrictsMovement</th>
#       <th>meansOfControlUsesChildren</th>
#       <th>meansOfControlThreatOfLawEnforcement</th>
#       <th>isForcedLabour</th>
#       <th>isSexualExploit</th>
#       <th>isOtherExploit</th>
#       <th>isAbduction</th>
#       <th>recruiterRelationIntimatePartner</th>
#       <th>recruiterRelationFriend</th>
#       <th>recruiterRelationFamily</th>
#       <th>recruiterRelationOther</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015</td>
# ...

# %%
#Filter by country 

#US = df['citizenship'] == "US"
#US_df = df[US]
US_df.head()
# Out:
#        By using this data you agree to the Terms of Use: https://www.ctdatacollaborative.org/terms-use  \
# 18733                                                NaN
# 18734                                                NaN
# 18735                                                NaN
# 18736                                                NaN
# 18737                                                NaN
#
#        yearOfRegistration Datasource  gender ageBroad majorityStatus  \
# 18733                2015    Hotline  Female   18--20          Adult
# 18734                2015    Hotline  Female   18--20          Adult
# 18735                2015    Hotline  Female   18--20          Adult
# 18736                2015    Hotline  Female   18--20          Adult
# 18737                2015    Hotline  Female   18--20          Adult
#
#       majorityStatusAtExploit majorityEntry citizenship  \
# 18733                   Minor           -99          US
# ...

# %%
#Clean dataframe

new_df = US_df[['yearOfRegistration', 'Datasource', 'gender', 'ageBroad', 'majorityStatus', 'majorityStatusAtExploit', 'citizenship', 'meansOfControlTakesEarnings', 'meansOfControlThreats', 'meansOfControlPsychologicalAbuse',
            'meansOfControlPhysicalAbuse', 'meansOfControlSexualAbuse', 'meansOfControlPsychoactiveSubstances', 'meansOfControlRestrictsMovement', 'meansOfControlUsesChildren', 'meansOfControlThreatOfLawEnforcement','isForcedLabour', 'isSexualExploit', 'isOtherExploit', 'isAbduction',
            'recruiterRelationIntimatePartner', 'recruiterRelationFriend', 'recruiterRelationFamily', 'recruiterRelationOther']]
new_df.head()
# Out:
#        yearOfRegistration Datasource  gender ageBroad majorityStatus  \
# 18733                2015    Hotline  Female   18--20          Adult
# 18734                2015    Hotline  Female   18--20          Adult
# 18735                2015    Hotline  Female   18--20          Adult
# 18736                2015    Hotline  Female   18--20          Adult
# 18737                2015    Hotline  Female   18--20          Adult
#
#       majorityStatusAtExploit citizenship  meansOfControlTakesEarnings  \
# 18733                   Minor          US                          -99
# 18734                   Adult          US                          -99
# 18735                   Minor          US                          -99
# 18736                     -99          US                          -99
# 18737                     -99          US                          -99
#
#        meansOfControlThreats  meansOfControlPsychologicalAbuse  ...  \
# ...

# %%
#Create new csv 

#new_df.to_csv ("new_global_dataset_2020.csv")
new_df.to_csv ("Data/new_global_dataset_2020.csv")
